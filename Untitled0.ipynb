# %%
# Mount Google Drive (if needed for dataset upload)
from google.colab import drive
drive.mount('/content/drive')

# Install required libraries (if not already installed)
# !pip install tensorflow pandas matplotlib scikit-learn

# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler

# Load dataset (UPLOAD your CSV file first!)
from google.colab import files
uploaded = files.upload()

# Read the dataset
df = pd.read_csv("housing_index_final.csv", parse_dates=["Date"])

# Convert Date to Year-Month numeric format
df["YearMonth"] = df["Date"].dt.year + (df["Date"].dt.month - 1) / 12
geographies = df["Geography"].unique()  # Get unique geography names

# Dictionary to store predictions for each geography
future_predictions_dict = {}

# Set sequence length (12 months)
sequence_length = 12

# Loop through each geography and apply LSTM
for geo in geographies:
    print(f"Training model for {geo}...")

    # Filter data for the specific geography
    df_geo = df[df["Geography"] == geo].groupby("YearMonth")["Index Value"].mean().reset_index()

    # Scale data
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(df_geo[["Index Value"]])

    # Create sequences
    X_train, y_train = [], []
    for i in range(sequence_length, len(scaled_data)):
        X_train.append(scaled_data[i-sequence_length:i, 0])  # Last 12 months
        y_train.append(scaled_data[i, 0])  # Next month's HPI

    X_train, y_train = np.array(X_train), np.array(y_train)
    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))  # Reshape for LSTM

    # Build LSTM model
    model = Sequential([
        LSTM(50, activation='relu', return_sequences=True, input_shape=(sequence_length, 1)),
        LSTM(50, activation='relu'),
        Dense(1)  # Output layer
    ])

    model.compile(optimizer='adam', loss='mse')
    model.fit(X_train, y_train, epochs=50, batch_size=16, verbose=0)

    # Predict future values (2025-2030)
    future_predictions = []
    input_seq = X_train[-1]  # Start with last known sequence

    for _ in range(72):  # Predicting 6 years (12 months x 6)
        pred = model.predict(input_seq.reshape(1, sequence_length, 1))
        future_predictions.append(pred[0, 0])
        input_seq = np.roll(input_seq, -1)  # Shift sequence
        input_seq[-1] = pred  # Add new prediction

    # Reverse scale predictions
    future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))

    # Generate future dates (from 2025-01 to 2030-12)
    future_dates = pd.date_range(start="2025-01-01", periods=72, freq="M")

    # Store results in a dictionary
    future_predictions_dict[geo] = pd.DataFrame({"Date": future_dates, "Predicted HPI": future_predictions.flatten()})

    # Plot results for the geography
    plt.figure(figsize=(12, 5))
    plt.plot(df_geo["YearMonth"], df_geo["Index Value"], label="Actual Data", color="blue")
    plt.plot(future_dates, future_predictions, label="Predicted (2025-2030)", color="red", linestyle="dashed")
    plt.xlabel("Year")
    plt.ylabel("Housing Price Index")
    plt.title(f"LSTM Prediction of Housing Price Index for {geo} (2025-2030)")
    plt.legend()
    plt.grid()
    plt.show()

# Combine predictions for all geographies
all_predictions = pd.concat(future_predictions_dict, names=["Geography"])
all_predictions.reset_index(inplace=True)

# Save predictions to CSV file
all_predictions.to_csv("HPI_predictions_2025_2030.csv", index=False)

# Display predictions for first few regions
print(all_predictions.head(30))  # Show first few rows
# Out:
# Mounted at /content/drive
# ...
#      <input type="file" id="files-194c5a55-2dee-4c17-b794-ed1e394e865c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-194c5a55-2dee-4c17-b794-ed1e394e865c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler
import os

# Load the dataset
df = pd.read_csv("housing_index_final.csv")
df["Date"] = pd.to_datetime(df["Date"])
df = df.sort_values("Date")

# Get unique regions
regions = df["Geography"].unique()

# Directory for saving models
model_dir = "saved_models"
os.makedirs(model_dir, exist_ok=True)

# Function to create sequences
def create_sequences(data, seq_length=12):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
    return np.array(X), np.array(y)

seq_length = 12  # Using past 12 months
future_steps = 72  # Predicting 6 years (2025-2030)

# Dictionary to store predictions
predictions = {}

for region in regions:
    df_region = df[df["Geography"] == region].sort_values("Date")

    # Prepare data
    scaler = MinMaxScaler()
    df_region["Scaled_Index"] = scaler.fit_transform(df_region[["Index Value"]])

    X, y = create_sequences(df_region["Scaled_Index"].values, seq_length)
    train_size = int(len(X) * 0.8)
    X_train, X_test = X[:train_size], X[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]

    model_path = os.path.join(model_dir, f"lstm_{region}.h5")

    if not os.path.exists(model_path):
        # Build LSTM Model
        model = Sequential([
            LSTM(50, return_sequences=True, input_shape=(seq_length, 1)),
            Dropout(0.2),
            LSTM(50, return_sequences=False),
            Dropout(0.2),
            Dense(25),
            Dense(1)
        ])

        model.compile(optimizer='adam', loss='mse')
        model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_test, y_test), verbose=1)
        model.save(model_path)  # Save model
    else:
        model = load_model(model_path)  # Load pre-trained model

    # Predict future values
    future_preds = []
    input_seq = X[-1].reshape(1, seq_length, 1)

    for _ in range(future_steps):
        pred = model.predict(input_seq, verbose=0)[0][0]
        future_preds.append(pred)
        input_seq = np.append(input_seq[:, 1:, :], [[[pred]]], axis=1)

    # Rescale predictions
    future_preds = scaler.inverse_transform(np.array(future_preds).reshape(-1, 1))
    date_range = pd.date_range(start=df_region["Date"].max(), periods=future_steps+1, freq='M')[1:]

    predictions[region] = (date_range, future_preds)

# Plot results
plt.figure(figsize=(12,5))
for region, (dates, preds) in predictions.items():
    df_region = df[df["Geography"] == region]
    plt.plot(df_region["Date"], df_region["Index Value"], label=f"Actual Data ({region})")
    plt.plot(dates, preds, linestyle='dashed', label=f"Predicted (2025-2030) ({region})")

plt.title("LSTM Prediction of Housing Price Index for All Regions (2025-2030)")
plt.xlabel("Year")
plt.ylabel("Housing Price Index")
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 13s 709ms/step - loss: 0.2636 - val_loss: 0.1701
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step - loss: 0.0774 - val_loss: 0.0392
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 186ms/step - loss: 0.0413 - val_loss: 0.1342
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 198ms/step - loss: 0.0331 - val_loss: 0.0199
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 0.0248 - val_loss: 0.0036
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0332 - val_loss: 0.0075
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0275 - val_loss: 2.7351e-04
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0228 - val_loss: 0.0298
# ...

# %%
# !pip install streamlit plotly pandas numpy tensorflow scikit-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 47.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 65.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 6.4 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler
import os
import ipywidgets as widgets
from IPython.display import display

# Load the dataset
df = pd.read_csv("housing_index_final.csv")
df["Date"] = pd.to_datetime(df["Date"])
df = df.sort_values("Date")

# Get unique regions
regions = df["Geography"].unique()

# Directory for saving models
model_dir = "saved_models"
os.makedirs(model_dir, exist_ok=True)

# Function to create sequences
def create_sequences(data, seq_length=12):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
    return np.array(X), np.array(y)

seq_length = 12  # Using past 12 months
future_steps = 72  # Predicting 6 years (2025-2030)

# Dictionary to store predictions
predictions = {}

for region in regions:
    df_region = df[df["Geography"] == region].sort_values("Date")

    # Prepare data
    scaler = MinMaxScaler()
    df_region["Scaled_Index"] = scaler.fit_transform(df_region[["Index Value"]])

    X, y = create_sequences(df_region["Scaled_Index"].values, seq_length)
    train_size = int(len(X) * 0.8)
    X_train, X_test = X[:train_size], X[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]

    model_path = os.path.join(model_dir, f"lstm_{region}.h5")

    if not os.path.exists(model_path):
        # Build LSTM Model
        model = Sequential([
            LSTM(50, return_sequences=True, input_shape=(seq_length, 1)),
            Dropout(0.2),
            LSTM(50, return_sequences=False),
            Dropout(0.2),
            Dense(25),
            Dense(1)
        ])

        model.compile(optimizer='adam', loss='mse')
        model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_test, y_test), verbose=1)
        model.save(model_path, save_format="h5", include_optimizer=False)  # Save model without optimizer
    else:
        model = load_model(model_path, compile=False)  # Load pre-trained model without compiling
        model.compile(optimizer='adam', loss='mse')  # Recompile model

    # Predict future values
    future_preds = []
    input_seq = X[-1].reshape(1, seq_length, 1)

    for _ in range(future_steps):
        pred = model.predict(input_seq, verbose=0)[0][0]
        future_preds.append(pred)
        input_seq = np.append(input_seq[:, 1:, :], [[[pred]]], axis=1)

    # Rescale predictions
    future_preds = scaler.inverse_transform(np.array(future_preds).reshape(-1, 1))
    date_range = pd.date_range(start=df_region["Date"].max(), periods=future_steps+1, freq='M')[1:]

    predictions[region] = (date_range, future_preds)

# Create interactive dropdown
dropdown = widgets.Dropdown(
    options=regions,
    description='Region:',
    disabled=False,
)

def plot_region(region):
    df_region = df[df["Geography"] == region]
    dates, preds = predictions[region]
    plt.figure(figsize=(12,5))
    plt.plot(df_region["Date"], df_region["Index Value"], label=f"Actual Data ({region})")
    plt.plot(dates, preds, linestyle='dashed', label=f"Predicted (2025-2030) ({region})")
    plt.title(f"LSTM Prediction of Housing Price Index for {region} (2025-2030)")
    plt.xlabel("Year")
    plt.ylabel("Housing Price Index")
    plt.legend()
    plt.show()

widgets.interactive(plot_region, region=dropdown)
# Out:
# <ipython-input-4-c8d654dc4c65>:81: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   date_range = pd.date_range(start=df_region["Date"].max(), periods=future_steps+1, freq='M')[1:]
# <ipython-input-4-c8d654dc4c65>:81: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   date_range = pd.date_range(start=df_region["Date"].max(), periods=future_steps+1, freq='M')[1:]
# <ipython-input-4-c8d654dc4c65>:81: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   date_range = pd.date_range(start=df_region["Date"].max(), periods=future_steps+1, freq='M')[1:]
# <ipython-input-4-c8d654dc4c65>:81: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   date_range = pd.date_range(start=df_region["Date"].max(), periods=future_steps+1, freq='M')[1:]
# ...

# %%
from flask import Flask, request, jsonify
import numpy as np
import pandas as pd
import os
from tensorflow.keras.models import load_model
from sklearn.preprocessing import MinMaxScaler

app = Flask(__name__)

# Load dataset (UPLOAD your CSV file first!)
from google.colab import files
uploaded = files.upload()


# Load dataset
df = pd.read_csv("housing_index_final.csv")
df["Date"] = pd.to_datetime(df["Date"])
df = df.sort_values("Date")

model_dir = "saved_models"

def load_trained_model(region):
    model_path = os.path.join(model_dir, f"lstm_{region}.h5")
    if os.path.exists(model_path):
        model = load_model(model_path, compile=False)
        model.compile(optimizer='adam', loss='mse')
        return model
    return None

def generate_predictions(region):
    df_region = df[df["Geography"] == region].sort_values("Date")

    # Scale data
    scaler = MinMaxScaler()
    df_region["Scaled_Index"] = scaler.fit_transform(df_region[["Index Value"]])

    seq_length = 12
    X = np.array([df_region["Scaled_Index"].values[-seq_length:]])
    model = load_trained_model(region)

    if model is None:
        return None, None

    future_preds = []
    input_seq = X.reshape(1, seq_length, 1)

    for _ in range(72):
        pred = model.predict(input_seq, verbose=0)[0][0]
        future_preds.append(pred)
        input_seq = np.append(input_seq[:, 1:, :], [[[pred]]], axis=1)

    future_preds = scaler.inverse_transform(np.array(future_preds).reshape(-1, 1))
    date_range = pd.date_range(start=df_region["Date"].max(), periods=73, freq='M')[1:]

    return date_range.strftime('%Y-%m-%d').tolist(), future_preds.flatten().tolist()

@app.route("/predict", methods=["GET"])
def predict():
    region = request.args.get("region")
    if region not in df["Geography"].unique():
        return jsonify({"error": "Region not found"}), 400

    dates, preds = generate_predictions(region)
    return jsonify({"region": region, "dates": dates, "predictions": preds})

if __name__ == "__main__":
    app.run(debug=True)
# Out:
#      <input type="file" id="files-782ee131-e85f-4314-b063-9d8f6201a9db" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-782ee131-e85f-4314-b063-9d8f6201a9db">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
